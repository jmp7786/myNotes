# %%
import win32com.client
import ctypes

################################################
# PLUS 공통 OBJECT
g_objCodeMgr = win32com.client.Dispatch('CpUtil.CpCodeMgr')
g_objCpStatus = win32com.client.Dispatch('CpUtil.CpCybos')
g_objCpTrade = win32com.client.Dispatch('CpTrade.CpTdUtil')

################################################
# PLUS 실행 기본 체크 함수
def InitPlusCheck():
    # 프로세스가 관리자 권한으로 실행 여부
    if ctypes.windll.shell32.IsUserAnAdmin():
        print('정상: 관리자권한으로 실행된 프로세스입니다.')
    else:
        print('오류: 일반권한으로 실행됨. 관리자 권한으로 실행해 주세요')
        return False

    # 연결 여부 체크
    if (g_objCpStatus.IsConnect == 0):
        print("PLUS가 정상적으로 연결되지 않음. ")
        return False

    # # 주문 관련 초기화 - 계좌 관련 코드가 있을 때만 사용
    # if (g_objCpTrade.TradeInit(0) != 0):
    #     pr"주문 초기화 실패")
    #     return False

    return True

class Cp7221:
    def __init__(self):
        self.objRq = win32com.client.Dispatch("CpSysDib.CpSvrNew7221")
        self.InvestIndex = {
            0: '거래소주식',
            1: '코스닥주식',
            2: '선물',
            3: '옵션콜',
            4: '옵션풋',
            5: '주식콜',
            6: '주식풋',
            7: '스타지수선물',
            8: '주식선물',
            9: '채권선물 3년국채(오픈예정)',
            10: '채권선물 5년국채(오픈예정)',
            11: '채권선물 10년국체(오픈예정)',
            12: '금리선물 CD(오픈예정)',
            13: '금리선물통안증권(오픈예정)',
            14: '통화선물미국달러(오픈예정)',
            15: '통화선물엔(오픈예정)',
            16: '통화선물유로(오픈예정)',
            17: '금속상품선물금(오픈예정)',
            18: '농산물파생선물돈육(오픈예정)',
            19: '통화콜옵션미국달러(오픈예정)',
            20: '통화풋옵션미국달러(오픈예정)',
            21: 'CME선물',
            22: '미니금선물'
        }

    def Request(self):
        self.objRq.SetInputValue(0, ord('1'))  # 옵션금액 선물계약
        self.objRq.BlockRequest()

        # 통신 및 통신 에러 처리
        rqStatus = self.objRq.GetDibStatus()
        print("통신상태", rqStatus, self.objRq.GetDibMsg1())
        if rqStatus != 0:
            return False

        cnt =  self.objRq.GetHeaderValue(1)
        for key, value in self.InvestIndex.items():
            dicInvest = {}
            dicInvest['개인매도'] = self.objRq.GetDataValue(0, key)
            dicInvest['개인매수'] = self.objRq.GetDataValue(1, key)
            dicInvest['개인순매수'] = self.objRq.GetDataValue(2, key)
            dicInvest['외국인매도'] = self.objRq.GetDataValue(3, key)
            dicInvest['외국인매수'] = self.objRq.GetDataValue(4, key)
            dicInvest['외국인순매수'] = self.objRq.GetDataValue(5, key) 
            dicInvest['기관매도'] = self.objRq.GetDataValue(6, key)
            dicInvest['기관매수'] = self.objRq.GetDataValue(7, key)
            dicInvest['기관순매수'] = self.objRq.GetDataValue(8, key)

            print(value)
            print(dicInvest)


if __name__ == "__main__":
    InitPlusCheck()
    objMarket = Cp7221()
    objMarket.Request()
# Out:
# 정상: 관리자권한으로 실행된 프로세스입니다.
# 통신상태 0 0027 조회가 완료되었습니다.(stock.total.invest)
# 거래소주식
# {'개인매도': 4727558, '개인매수': 4039503, '개인순매수': -688055, '외국인매도': 2024497, '외국인매수': 2183052, '외국인순매수': 158555, '기관매도': 1522686, '기관매수': 2039388, '기관순매수': 516702}
# 코스닥주식
# {'개인매도': 3830021, '개인매수': 3806598, '개인순매수': -23423, '외국인매도': 488123, '외국인매수': 552673, '외국인순매수': 64550, '기관매도': 241340, '기관매수': 200151, '기관순매수': -41189}
# 선물
# {'개인매도': 89982, '개인매수': 90216, '개인순매수': 234, '외국인매도': 250856, '외국인매수': 252134, '외국인순매수': 1278, '기관매도': 45702, '기관매수': 42820, '기관순매수': -2882}
# 옵션콜
# {'개인매도': 215068, '개인매수': 215534, '개인순매수': 466, '외국인매도': 603020, '외국인매수': 621456, '외국인순매수': 18436, '기관매도': 58204, '기관매수': 34969, '기관순매수': -23235}
# 옵션풋
# {'개인매도': 121003, '개인매수': 121207, '개인순매수': 204, '외국인매도': 365334, '외국인매수': 363389, '외국인순매수': -1945, '기관매도': 21675, '기관매수': 25601, '기관순매수': 3926}
# 주식콜
# {'개인매도': 233, '개인매수': 147, '개인순매수': -86, '외국인매도': 0, '외국인매수': 0, '외국인순매수': 0, '기관매도': 425, '기관매수': 511, '기관순매수': 86}
# 주식풋
# {'개인매도': 89, '개인매수': 74, '개인순매수': -15, '외국인매도': 0, '외국인매수': 0, '외국인순매수': 0, '기관매도': 183, '기관매수': 199, '기관순매수': 16}
# 스타지수선물
# {'개인매도': 0, '개인매수': 0, '개인순매수': 0, '외국인매도': 0, '외국인매수': 0, '외국인순매수': 0, '기관매도': 0, '기관매수': 0, '기관순매수': 0}
# 주식선물
# {'개인매도': 703048, '개인매수': 720131, '개인순매수': 17083, '외국인매도': 1377113, '외국인매수': 1422659, '외국인순매수': 45546, '기관매도': 1335737, '기관매수': 1210865, '기관순매수': -124872}
# 채권선물 3년국채(오픈예정)
# {'개인매도': 1313, '개인매수': 1308, '개인순매수': -5, '외국인매도': 23, '외국인매수': 0, '외국인순매수': -23, '기관매도': 84, '기관매수': 110, '기관순매수': 26}
# 채권선물 5년국채(오픈예정)
# {'개인매도': 919572, '개인매수': 895941, '개인순매수': -23631, '외국인매도': 633702, '외국인매수': 676370, '외국인순매수': 42668, '기관매도': 671066, '기관매수': 655368, '기관순매수': -15698}
# 채권선물 10년국체(오픈예정)
# {'개인매도': 125080, '개인매수': 118726, '개인순매수': -6354, '외국인매도': 120473, '외국인매수': 113302, '외국인순매수': -7171, '기관매도': 20430, '기관매수': 34037, '기관순매수': 13607}
# 금리선물 CD(오픈예정)
# {'개인매도': 13818, '개인매수': 13289, '개인순매수': -529, '외국인매도': 87764, '외국인매수': 91891, '외국인순매수': 4127, '기관매도': 53880, '기관매수': 50297, '기관순매수': -3583}
# 금리선물통안증권(오픈예정)
# {'개인매도': 1, '개인매수': 0, '개인순매수': -1, '외국인매도': 157, '외국인매수': 127, '외국인순매수': -30, '기관매도': 368, '기관매수': 399, '기관순매수': 31}
# 통화선물미국달러(오픈예정)
# {'개인매도': 69275, '개인매수': 69674, '개인순매수': 399, '외국인매도': 263388, '외국인매수': 257633, '외국인순매수': -5755, '기관매도': 124810, '기관매수': 128766, '기관순매수': 3956}
# 통화선물엔(오픈예정)
# {'개인매도': 109, '개인매수': 376, '개인순매수': 267, '외국인매도': 150, '외국인매수': 150, '외국인순매수': 0, '기관매도': 1350, '기관매수': 999, '기관순매수': -351}
# 통화선물유로(오픈예정)
# {'개인매도': 0, '개인매수': 1277, '개인순매수': 1277, '외국인매도': 0, '외국인매수': 0, '외국인순매수': 0, '기관매도': 1783, '기관매수': 371, '기관순매수': -1412}
# 금속상품선물금(오픈예정)
# {'개인매도': 0, '개인매수': 0, '개인순매수': 0, '외국인매도': 0, '외국인매수': 0, '외국인순매수': 0, '기관매도': 15, '기관매수': 15, '기관순매수': 0}
# 농산물파생선물돈육(오픈예정)
# {'개인매도': 0, '개인매수': 0, '개인순매수': 0, '외국인매도': 0, '외국인매수': 0, '외국인순매수': 0, '기관매도': 0, '기관매수': 0, '기관순매수': 0}
# 통화콜옵션미국달러(오픈예정)
# {'개인매도': 0, '개인매수': 0, '개인순매수': 0, '외국인매도': 0, '외국인매수': 0, '외국인순매수': 0, '기관매도': 0, '기관매수': 0, '기관순매수': 0}
# 통화풋옵션미국달러(오픈예정)
# {'개인매도': 0, '개인매수': 0, '개인순매수': 0, '외국인매도': 0, '외국인매수': 0, '외국인순매수': 0, '기관매도': 0, '기관매수': 0, '기관순매수': 0}
# CME선물
# {'개인매도': 3830, '개인매수': 4833, '개인순매수': 1003, '외국인매도': 5688, '외국인매수': 4580, '외국인순매수': -1108, '기관매도': 65, '기관매수': 179, '기관순매수': 114}
# 미니금선물
# {'개인매도': 0, '개인매수': 0, '개인순매수': 0, '외국인매도': 0, '외국인매수': 0, '외국인순매수': 0, '기관매도': 0, '기관매수': 0, '기관순매수': 0}
